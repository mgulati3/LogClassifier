# %%
import pandas as pd

# %%
df = pd.read_csv('synthetic_logs.csv')
df.head(3)
# Out:
#              timestamp           source  \
# 0  2025-06-27 07:20:25        ModernCRM
# 1      1/14/2025 23:07        ModernCRM
# 2       1/17/2025 1:29  AnalyticsEngine
#
#                                          log_message    target_label  \
# 0  nova.osapi_compute.wsgi.server [req-b9718cd8-f...     HTTP Status
# 1     Email service experiencing issues with sending  Critical Error
# 2          Unauthorized access to data was attempted  Security Alert
#
#   complexity
# 0       bert
# 1       bert
# 2       bert

# %%
df.source.unique()
# Out:
# array(['ModernCRM', 'AnalyticsEngine', 'ModernHR', 'BillingSystem',
#        'ThirdPartyAPI', 'LegacyCRM'], dtype=object)

# %%
df.target_label.unique()
# Out:
# array(['HTTP Status', 'Critical Error', 'Security Alert', 'Error',
#        'System Notification', 'Resource Usage', 'User Action',
#        'Workflow Error', 'Deprecation Warning'], dtype=object)

# %%
df[df.target_label=='System Notification'].sample(10)
# Out:
#              timestamp         source  \
# 2304   11/10/2025 9:39       ModernHR
# 14       1/4/2025 1:43  ThirdPartyAPI
# 2256  12/26/2025 14:07  ThirdPartyAPI
# 913     7/26/2025 2:50  ThirdPartyAPI
# 1907     6/7/2025 4:43  BillingSystem
# 866     12/3/2025 4:16      ModernCRM
# 1637   2/27/2025 17:24      ModernCRM
# 2313     9/8/2025 1:45  ThirdPartyAPI
# 928    3/29/2025 15:58      ModernCRM
# 1274    8/9/2025 17:23      ModernCRM
#
#                                             log_message         target_label  \
# 2304             Backup started at 2025-09-08 22:36:53.  System Notification
# 14    File data_3847.csv uploaded successfully by us...  System Notification
# 2256  File data_6957.csv uploaded successfully by us...  System Notification
# 913                    System updated to version 4.6.3.  System Notification
# 1907               Backup ended at 2025-04-13 10:00:34.  System Notification
# 866                      Backup completed successfully.  System Notification
# 1637                     Backup completed successfully.  System Notification
# 2313                   System updated to version 5.8.4.  System Notification
# 928                    System updated to version 4.4.0.  System Notification
# 1274               Backup ended at 2025-10-17 19:00:39.  System Notification
#
#      complexity  cluster
# 2304      regex        8
# 14        regex        2
# 2256      regex        2
# 913       regex       13
# 1907      regex        8
# 866       regex        4
# 1637      regex        4
# 2313      regex       13
# 928       regex       13
# 1274      regex        8

# %%
df[df.log_message.str.startswith("System reboot initiated by user")]
# Out:
#              timestamp           source  \
# 36    11/19/2025 13:14    BillingSystem
# 92     12/4/2025 21:20    BillingSystem
# 139     5/8/2025 16:34         ModernHR
# 140     9/11/2025 8:49  AnalyticsEngine
# 161    3/31/2025 19:40    BillingSystem
# 163     6/6/2025 15:29    BillingSystem
# 307     4/12/2025 0:41    BillingSystem
# 365   10/20/2025 22:32         ModernHR
# 508     4/15/2025 2:04    ThirdPartyAPI
# 552    9/22/2025 20:54         ModernHR
# 668      9/5/2025 7:14         ModernHR
# 693     7/6/2025 21:40    BillingSystem
# 697     3/13/2025 7:09    BillingSystem
# 714    9/25/2025 23:35    ThirdPartyAPI
# 730    5/24/2025 11:08  AnalyticsEngine
# 800    8/15/2025 12:14    BillingSystem
# 837      4/9/2025 8:28  AnalyticsEngine
# 852     3/31/2025 5:20        ModernCRM
# 865     2/25/2025 1:40  AnalyticsEngine
# 889   11/30/2025 13:45         ModernHR
# 896    7/28/2025 11:24    BillingSystem
# 988    9/11/2025 22:23    BillingSystem
# 1106  12/28/2025 13:32         ModernHR
# 1159     8/5/2025 6:52    BillingSystem
# 1194    7/20/2025 9:10  AnalyticsEngine
# 1275   7/15/2025 23:37    BillingSystem
# 1299   7/15/2025 19:19    BillingSystem
# 1304    8/10/2025 6:18    ThirdPartyAPI
# 1524   11/30/2025 2:39    ThirdPartyAPI
# 1562    8/18/2025 4:17    ThirdPartyAPI
# 1624   12/14/2025 5:14  AnalyticsEngine
# 1663  10/27/2025 22:04  AnalyticsEngine
# 1776   2/21/2025 11:56         ModernHR
# 1803    8/22/2025 6:30  AnalyticsEngine
# 1804   8/26/2025 21:06         ModernHR
# 1852   1/26/2025 12:34  AnalyticsEngine
# 1865   5/11/2025 10:58  AnalyticsEngine
# 1956   9/26/2025 19:32    ThirdPartyAPI
# 2003   6/23/2025 17:54        ModernCRM
# 2014   12/25/2025 4:33  AnalyticsEngine
# 2043   9/12/2025 20:20    ThirdPartyAPI
# 2074    9/13/2025 8:43        ModernCRM
# 2228    9/3/2025 11:24         ModernHR
# 2243    1/16/2025 7:22         ModernHR
# 2246    3/2/2025 22:56         ModernHR
# 2253    10/7/2025 2:20         ModernHR
# 2317     3/7/2025 5:44    BillingSystem
# 2360     5/1/2025 4:21    ThirdPartyAPI
#
#                                    log_message         target_label  \
# 36    System reboot initiated by user User243.  System Notification
# 92    System reboot initiated by user User471.  System Notification
# 139   System reboot initiated by user User216.  System Notification
# 140   System reboot initiated by user User639.  System Notification
# 161   System reboot initiated by user User819.  System Notification
# 163   System reboot initiated by user User938.  System Notification
# 307   System reboot initiated by user User929.  System Notification
# 365   System reboot initiated by user User533.  System Notification
# 508   System reboot initiated by user User591.  System Notification
# 552   System reboot initiated by user User421.  System Notification
# 668   System reboot initiated by user User297.  System Notification
# 693   System reboot initiated by user User159.  System Notification
# 697   System reboot initiated by user User648.  System Notification
# 714   System reboot initiated by user User600.  System Notification
# 730   System reboot initiated by user User120.  System Notification
# 800   System reboot initiated by user User901.  System Notification
# 837   System reboot initiated by user User876.  System Notification
# 852   System reboot initiated by user User811.  System Notification
# 865   System reboot initiated by user User964.  System Notification
# 889   System reboot initiated by user User766.  System Notification
# 896   System reboot initiated by user User765.  System Notification
# 988   System reboot initiated by user User427.  System Notification
# 1106  System reboot initiated by user User246.  System Notification
# 1159  System reboot initiated by user User329.  System Notification
# 1194  System reboot initiated by user User747.  System Notification
# 1275  System reboot initiated by user User829.  System Notification
# 1299  System reboot initiated by user User966.  System Notification
# 1304  System reboot initiated by user User758.  System Notification
# 1524  System reboot initiated by user User278.  System Notification
# 1562  System reboot initiated by user User648.  System Notification
# 1624  System reboot initiated by user User268.  System Notification
# 1663  System reboot initiated by user User315.  System Notification
# 1776  System reboot initiated by user User155.  System Notification
# 1803  System reboot initiated by user User204.  System Notification
# 1804  System reboot initiated by user User899.  System Notification
# 1852  System reboot initiated by user User223.  System Notification
# 1865  System reboot initiated by user User932.  System Notification
# 1956  System reboot initiated by user User264.  System Notification
# 2003  System reboot initiated by user User517.  System Notification
# 2014  System reboot initiated by user User293.  System Notification
# 2043  System reboot initiated by user User262.  System Notification
# 2074  System reboot initiated by user User937.  System Notification
# 2228  System reboot initiated by user User179.  System Notification
# 2243  System reboot initiated by user User770.  System Notification
# 2246  System reboot initiated by user User488.  System Notification
# 2253  System reboot initiated by user User644.  System Notification
# 2317  System reboot initiated by user User724.  System Notification
# 2360  System reboot initiated by user User876.  System Notification
#
#      complexity  cluster
# 36        regex       11
# 92        regex       11
# 139       regex       11
# 140       regex       11
# 161       regex       11
# 163       regex       11
# 307       regex       11
# 365       regex       11
# 508       regex       11
# 552       regex       11
# 668       regex       11
# 693       regex       11
# 697       regex       11
# 714       regex       11
# 730       regex       11
# 800       regex       11
# 837       regex       11
# 852       regex       11
# 865       regex       11
# 889       regex       11
# 896       regex       11
# 988       regex       11
# 1106      regex       11
# 1159      regex       11
# 1194      regex       11
# 1275      regex       11
# 1299      regex       11
# 1304      regex       11
# 1524      regex       11
# 1562      regex       11
# 1624      regex       11
# 1663      regex       11
# 1776      regex       11
# 1803      regex       11
# 1804      regex       11
# 1852      regex       11
# 1865      regex       11
# 1956      regex       11
# 2003      regex       11
# 2014      regex       11
# 2043      regex       11
# 2074      regex       11
# 2228      regex       11
# 2243      regex       11
# 2246      regex       11
# 2253      regex       11
# 2317      regex       11
# 2360      regex       11

# %% [markdown]
# # Clustering

# %%
# !pip install -q -U sentence-transformers scikit-learn
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 470.2/470.2 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 50.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 40.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 30.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 38.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 8.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 34.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sklearn-compat 0.1.3 requires scikit-learn<1.7,>=1.2, but you have scikit-learn 1.7.0 which is incompatible.

# %%
from sentence_transformers import SentenceTransformer
from sklearn.cluster import DBSCAN
import numpy as np

# Load a pre-trained Sentence Transformer model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Generate embeddings for the log messages
embeddings = model.encode(df['log_message'].tolist())

print(embeddings[:2])
# Out:
# [[-1.02939598e-01  3.35459486e-02 -2.20260844e-02  1.55103172e-03
#   -9.86921880e-03 -1.78956211e-01 -6.34409934e-02 -6.01761453e-02
#    2.81108953e-02  5.99620081e-02 -1.72618236e-02  1.43364200e-03
#   -1.49560079e-01  3.15288268e-03 -5.66030741e-02  2.71685328e-02
#   -1.49890278e-02 -3.54037210e-02 -3.62936370e-02 -1.45410486e-02
#   -5.61492983e-03  8.75538811e-02  4.55120727e-02  2.50963680e-02
#    1.00187613e-02  1.24267004e-02 -1.39923558e-01  7.68696666e-02
#    3.14095393e-02 -4.15247958e-03  4.36902344e-02  1.71249956e-02
#   -8.00950900e-02  5.74006140e-02  1.89092122e-02  8.55262056e-02
#    3.96399088e-02 -1.34371832e-01 -1.44367013e-03  3.06707830e-03
#    1.76854059e-01  4.44890792e-03 -1.69275142e-02  2.24266183e-02
#   -4.35049757e-02  6.09031972e-03 -9.98171885e-03 -6.23973012e-02
#    1.07372692e-02 -6.04895223e-03 -7.14661255e-02 -8.45800899e-03
#   -3.18019874e-02 -1.00518353e-01  2.25892727e-04 -1.89341605e-02
#   -3.17793749e-02  4.00861092e-02  2.19178014e-02 -2.59528570e-02
#    5.84524833e-02 -8.12509656e-02  2.12029386e-02 -5.02687544e-02
#    1.32056857e-02  1.32681162e-03  2.27062758e-02 -3.45794074e-02
#    3.91546786e-02 -2.09433492e-02  3.24822357e-03  4.43961024e-02
#   -9.85358134e-02 -2.88895480e-02 -6.85024215e-03  5.38819097e-02
#    6.46110177e-02 -2.45060828e-02  9.21828821e-02 -7.49868974e-02
#    1.23994965e-02 -1.00026578e-01 -4.64910679e-02  6.01569898e-02
#   -2.46480461e-02 -7.08076060e-02 -2.77271084e-02  9.72610563e-02
#    3.85841243e-02 -1.44293215e-02 -7.46876060e-04 -1.04305558e-02
#   -1.61843076e-02  4.43628244e-02  9.25995782e-03  7.14165643e-02
#    6.37917668e-02  4.94931154e-02 -6.02567866e-02  4.04805355e-02
#   -3.42860296e-02 -1.93881392e-02  6.61234260e-02  6.01589940e-02
#    1.09371496e-02 -5.38629945e-03  1.44580016e-02  9.25429761e-02
#   -3.14564258e-02 -1.84351988e-02  9.91879404e-03 -1.85574368e-02
#    1.31281465e-03  2.26563407e-05  2.02739448e-03  2.75256820e-02
#   -4.81927916e-02  5.42825609e-02 -7.32067153e-02  4.88667339e-02
#    4.98489924e-02 -9.01142415e-03 -4.68906164e-02 -4.25886661e-02
#   -8.19523782e-02  3.87106054e-02  7.85503089e-02  1.46077052e-32
#    1.66706461e-02  5.25494032e-02 -1.82448998e-02 -1.26686115e-02
#    6.52837232e-02 -2.11777352e-02 -4.06322591e-02  4.14947644e-02
#   -2.48361286e-02 -1.33068012e-02 -5.46753965e-02 -5.99142280e-04
#   -4.89243725e-03 -6.27359226e-02 -3.84878181e-02 -6.13544025e-02
#    8.27405304e-02  2.34380104e-02 -8.63093510e-03  1.31002879e-02
#    6.44215271e-02 -4.41361666e-02 -6.98633343e-02 -7.36060143e-02
#   -4.33264077e-02  6.96524372e-03 -5.05956821e-02 -1.60911884e-02
#   -5.66794015e-02  3.35454172e-03  5.34114838e-02  2.47761123e-02
#   -1.47985769e-02 -2.93243285e-02  7.30227977e-02 -1.86834130e-02
#    8.13137144e-02 -2.69967336e-02 -5.68056144e-02 -6.59389123e-02
#   -5.95397688e-03  2.85312925e-02 -7.85358027e-02 -2.76694074e-03
#   -3.26468586e-03 -9.28333029e-02 -7.27362633e-02 -3.31903175e-02
#    1.01411082e-01  9.79882032e-02 -9.78740007e-02  1.98667496e-02
#    2.38837264e-02 -1.81672256e-02 -3.73709053e-02  1.96549576e-03
#    6.34426102e-02  1.18271522e-02 -1.12041505e-02 -3.87316383e-02
#    9.32424143e-02  4.26629651e-03 -1.66872405e-02 -6.87463954e-02
#    1.55120483e-02 -4.97755222e-02  3.34492959e-02  8.00032243e-02
#    2.12281905e-02  1.34581909e-01 -2.30729971e-02  5.53858466e-02
#    3.07558216e-02 -2.93905493e-02  2.31905486e-02 -9.34308171e-02
#    7.58034810e-02 -5.21205226e-03 -5.14523126e-02  3.32689323e-02
#    3.67963053e-02 -1.06449798e-02  1.01635531e-02 -2.07651500e-02
#   -5.85519001e-02  4.79328074e-02  2.13694833e-02  8.76213238e-02
#    3.35493730e-03 -3.80336605e-02 -1.81204714e-02  6.87452592e-03
#    5.15879989e-02 -4.75598574e-02 -6.12065159e-02 -1.45483530e-32
#    4.12800722e-03  4.59645316e-03 -5.63900769e-02  4.32465272e-03
#   -1.09440682e-03  9.31954570e-03 -2.20268667e-02  5.79564609e-02
#   -1.44787570e-02  4.64155599e-02  1.43542871e-01 -6.89756721e-02
#    6.09631836e-02 -8.93743858e-02  2.40919348e-02  2.06010714e-02
#   -2.82416046e-02 -6.48315102e-02  5.64795919e-02 -7.48339668e-03
#   -3.52058560e-02  8.51060450e-02  1.30359819e-02  2.02257708e-02
#   -1.44390967e-02 -4.63718660e-02  1.77209731e-02  1.59105621e-02
#   -9.51009467e-02 -3.54526788e-02  2.08696090e-02  3.84385232e-03
#   -8.77917930e-02  6.44575506e-02  1.44171612e-02  3.84729309e-03
#    4.70991693e-02  4.94661517e-02  1.53862564e-02 -2.59578731e-02
#    9.10894498e-02  1.83307920e-02 -5.89206219e-02  2.51993146e-02
#   -3.30373794e-02  8.23344663e-02  1.74791757e-02  6.48047403e-02
#   -1.19674262e-02 -3.31778415e-02  3.00177317e-02  3.54220085e-02
#   -1.39624514e-02  6.69272989e-02  3.87919620e-02  6.06916696e-02
#    1.17957848e-03 -2.38786284e-02 -1.26930490e-01  1.13846632e-02
#    1.59290060e-02 -1.29426625e-02 -8.63247439e-02  8.53660703e-03
#    6.03761636e-02  1.51122436e-02 -1.19132407e-01  1.15234470e-02
#    5.97089268e-02 -3.93345952e-02  1.55673148e-02  1.04602342e-02
#   -4.72457036e-02 -2.59243064e-02  9.98528209e-03  3.07146013e-02
#   -7.14844689e-02  6.98967557e-03 -1.55133186e-02  2.18864325e-02
#   -2.78145522e-02  6.92733154e-02 -2.75903475e-02  2.62429547e-02
#    3.52561995e-02 -4.26419415e-02  7.46284961e-04  6.59867302e-02
#   -5.15105650e-02 -3.58434208e-02 -6.53442135e-03 -2.75858492e-02
#   -1.00125544e-01  7.83325955e-02 -1.45798773e-02 -6.18457179e-08
#    2.00325623e-02  6.59785196e-02 -2.04702597e-02  1.64043866e-02
#    7.63001367e-02  7.32182786e-02  5.65787451e-03 -6.97761949e-04
#   -3.63798416e-03  6.02394454e-02 -3.27187367e-02 -6.45837858e-02
#   -5.97952567e-02 -1.76695641e-02  6.10140571e-03 -5.63489553e-03
#   -1.22972250e-01  6.35818541e-02 -2.19431613e-02 -1.16406471e-01
#    2.34366171e-02 -7.23525435e-02  2.31773816e-02 -6.55986890e-02
#   -7.42681623e-02  2.60146093e-02  3.59758511e-02  7.68432766e-02
#   -3.08057144e-02 -2.34793816e-02 -6.30426183e-02 -3.62158455e-02
#   -1.03560099e-02 -4.75602038e-02 -2.87521929e-02  2.96400692e-02
#   -5.26895793e-03  5.67889959e-02 -3.74493655e-03  3.09612677e-02
#    3.48227136e-02  3.78607735e-02  2.10155528e-02  2.70691440e-02
#    5.25520556e-02  7.16229603e-02 -5.53756254e-03  4.01094146e-02
#    5.16276918e-02 -2.67314091e-02  5.94224073e-02 -4.29224223e-02
#   -1.19760558e-02  3.05985250e-02 -7.40331709e-02  1.84221864e-02
#   -8.64861067e-03 -8.83557424e-02 -5.91984391e-02 -1.00883713e-04
#    1.12913661e-01  4.57792962e-03 -4.25971635e-02  3.22622969e-03]
#  [ 8.04572552e-03 -3.57392393e-02  4.93873879e-02 -7.19184428e-03
#    6.17668557e-04 -9.05685127e-02  5.75595051e-02 -4.39446084e-02
#    1.74751449e-02  5.21203019e-02 -4.62332182e-02  2.49039270e-02
#    4.80811708e-02  6.86636493e-02  3.56146768e-02  3.00089214e-02
#    2.61449665e-02 -9.05241296e-02 -8.02174062e-02  5.04851379e-02
#   -7.90870339e-02 -1.76856481e-03 -2.48926803e-02  9.02152583e-02
#    5.83700649e-03 -6.91071302e-02 -6.67965934e-02 -6.99112937e-03
#   -1.04566008e-01 -2.66473945e-02  3.05639971e-02  2.02934481e-02
#    2.25454997e-02 -4.22683218e-03  1.11173103e-02  6.78260922e-02
#    1.06073283e-02  7.56636411e-02 -8.22777972e-02  8.45729839e-03
#   -6.97612464e-02 -4.21974547e-02 -1.05674835e-02  2.23673303e-02
#    5.64496815e-02  8.16503447e-03  1.09344080e-01  3.16565149e-02
#   -1.76923834e-02 -3.21071483e-02 -3.39975841e-02 -4.91824176e-04
#    3.72874900e-03  2.83771716e-02 -1.28521975e-02 -1.07929704e-03
#   -6.32418990e-02  6.89901039e-02  1.77270342e-02 -5.20959757e-02
#    8.28306563e-03  5.45033030e-02 -5.42099476e-02 -4.53332886e-02
#   -4.07494120e-02 -2.82698292e-02  1.23605812e-02 -2.13816036e-02
#   -2.36265752e-02  1.25317667e-02 -2.37170774e-02  3.97411510e-02
#   -1.24362260e-01  7.60625154e-02  5.50833866e-02  8.28216970e-02
#    2.97118686e-02 -1.84067395e-02 -1.96195096e-02  5.54319844e-02
#   -3.49144898e-02 -4.14678082e-02 -3.37047167e-02  7.31323957e-02
#    4.41836491e-02  2.55246554e-02 -8.26407690e-03 -1.07323052e-02
#   -4.26244102e-02 -2.84965336e-03  7.38559365e-02  2.27768235e-02
#    7.15367496e-04  4.36012410e-02  5.09079620e-02  6.38482794e-02
#   -2.73155775e-02 -6.55020997e-02 -7.69265220e-02  3.55171263e-02
#    9.60493460e-02  2.18195748e-02  1.20154498e-02 -1.17863659e-02
#   -4.57923487e-03 -8.58035777e-03  3.37151103e-02  2.31918078e-02
#   -7.58325234e-02 -5.23879528e-02  4.53934260e-02 -3.80786173e-02
#   -3.34904902e-02  9.20352712e-02  2.87688486e-02 -3.33816819e-02
#   -1.95854483e-03 -3.04567831e-04 -1.70498900e-02  2.85335761e-02
#   -8.81096795e-02 -4.02253121e-02 -4.00093235e-02 -1.03193168e-02
#   -2.51968503e-02  2.14093234e-02  1.31045222e-01 -5.29632066e-34
#   -1.09651729e-01  1.29811466e-02  5.92660019e-03  4.73506376e-02
#   -8.60298425e-03 -3.67089435e-02  3.05214953e-02  5.53066693e-02
#   -4.71985452e-02 -1.25118904e-02 -1.15366429e-01  9.08000953e-03
#    1.07346512e-01 -4.94734608e-02 -1.34290364e-02 -4.61562984e-02
#    2.45320387e-02  9.45075974e-03  2.04323996e-02 -3.99918705e-02
#   -4.67825718e-02  2.21171733e-02 -4.58187088e-02 -8.13276228e-03
#   -7.65674515e-03  1.92284770e-02  4.85845245e-02 -2.55903229e-02
#    1.61543780e-03 -1.37180379e-02  9.67301708e-03  7.36416224e-03
#    1.14088161e-02  1.28853455e-01  7.71834888e-03  7.06362575e-02
#    2.54452080e-02  4.06523831e-02  2.44039763e-02  1.43777151e-02
#   -6.00932278e-02  7.38180354e-02 -2.44700685e-02  8.98901448e-02
#    3.17049143e-03  1.01834461e-01  4.17742170e-02 -5.95177710e-02
#   -3.23181450e-02  3.80938686e-02  1.21156052e-02 -4.07834128e-02
#    2.84823179e-02  4.90988754e-02 -9.35705751e-03  6.50074407e-02
#    7.23532289e-02 -1.67793669e-02 -8.22419114e-03 -1.61573272e-02
#    5.96225597e-02 -3.36083509e-02  2.12108437e-02 -6.06090687e-02
#    1.54377639e-01 -7.24146217e-02 -3.77272367e-02 -3.26890349e-02
#   -1.80384610e-03 -1.01960413e-02 -1.60677417e-03 -6.91846386e-02
#    8.28444585e-02  9.88839567e-02  3.45466728e-03 -9.90247950e-02
#   -3.52827050e-02 -7.13178813e-02 -4.96000163e-02 -3.43954526e-02
#   -8.13041851e-02  4.81447987e-02  5.00680692e-03 -2.21499726e-02
#   -5.60056493e-02  1.00067109e-02 -3.59794237e-02  1.06184304e-01
#   -4.54196818e-02  7.16393366e-02 -2.36772913e-02  9.98142548e-03
#    2.73602176e-02  1.05985478e-01  4.60164063e-02  9.59027617e-34
#   -1.12306945e-01  2.78912578e-02 -3.35900523e-02  5.39242998e-02
#   -2.22291518e-02  1.53769441e-02  3.10411584e-02  3.39010768e-02
#    7.43167102e-02  3.42470929e-02 -3.35054635e-03 -2.05350593e-02
#   -3.62370312e-02  2.29334217e-02 -3.01991943e-02 -1.00819923e-01
#    3.29194255e-02  6.77542761e-02  1.35644944e-02 -5.20547107e-03
#   -6.58158809e-02  9.54550579e-02 -1.34039326e-02  1.53885940e-02
#   -7.22935945e-02  9.67835709e-02 -8.08119699e-02 -4.53452626e-03
#   -6.42011985e-02 -4.99278642e-02  4.64197397e-02  2.21341085e-02
#    3.13109383e-02  9.13569182e-02 -4.61120121e-02 -1.02761187e-01
#    3.04416120e-02  5.09876460e-02  6.70140833e-02  1.04043270e-02
#    1.63533799e-02  3.92030850e-02  2.17153914e-02  5.36603518e-02
#    3.62809636e-02 -4.22140211e-02 -2.47227196e-02  1.90311782e-02
#    3.61724123e-02  6.37021139e-02 -3.21578817e-03 -8.50387383e-03
#    3.94655615e-02  9.02654510e-03  1.93095915e-02  6.60717934e-02
#    1.02694957e-02 -4.43853773e-02 -1.56523194e-02 -1.55714676e-02
#    1.32904388e-02 -1.16108488e-02  4.21832129e-02 -5.44776581e-02
#    1.29237175e-01 -2.25756541e-02  5.26203774e-02 -1.58436857e-02
#    9.33164880e-02  6.38023904e-03 -9.36165638e-03 -6.08876199e-02
#   -3.27308029e-02 -3.44816707e-02  3.29974256e-02 -4.79391702e-02
#   -9.81300846e-02  2.91164871e-02 -2.70903241e-02  1.81866642e-02
#   -1.73860174e-02 -4.40371595e-02 -7.97002390e-02  3.01647373e-02
#   -6.35260642e-02  1.25963567e-02  8.50250348e-02 -4.58910652e-02
#    5.81016764e-02 -2.71002036e-02  8.42775702e-02 -4.09972519e-02
#   -3.37655805e-02  1.02087930e-02 -2.54193563e-02 -1.40610297e-08
#    4.94446792e-02 -9.04356763e-02 -6.06710315e-02  8.29529092e-02
#   -3.29032838e-02  4.14910503e-02  9.99593921e-03  6.96134334e-03
#    3.99234612e-03 -3.24333161e-02 -3.14657018e-02 -5.33161685e-02
#   -3.80913243e-02  1.62076969e-02  2.45778412e-02 -7.26419687e-02
#   -6.56893179e-02 -8.23132172e-02 -8.00500587e-02 -5.36649115e-02
#    5.60894459e-02 -1.10913245e-02  9.62154008e-04 -1.22690305e-01
#   -5.13836592e-02  9.96704213e-03  1.00696208e-02  1.07073084e-01
#    1.19758435e-02  1.00423899e-02 -6.28261715e-02 -7.49697462e-02
#   -6.34075888e-03 -2.72201151e-02 -1.28096193e-01 -2.62459628e-02
#   -1.81463920e-02 -9.85360220e-02 -3.02990526e-02 -4.02614959e-02
#    9.94291380e-02  5.35999611e-02  2.74899788e-02 -5.53685380e-03
#    8.43571350e-02  8.35162252e-02  3.74305025e-02  7.11937472e-02
#    2.98902746e-02  2.32728813e-02 -3.62111628e-02  6.20540269e-02
#    2.15148460e-02  5.19732684e-02  1.45337591e-02 -4.60966565e-02
#    5.02554327e-02 -7.27027506e-02  2.92779077e-02  5.62663190e-02
#   -3.86354737e-02  1.53832054e-02 -6.23095073e-02 -2.77466383e-02]]

# %%
dbscan = DBSCAN(eps=0.2, min_samples=1, metric='cosine')
clusters = dbscan.fit_predict(embeddings)

# Add the cluster labels to the DataFrame
df['cluster'] = clusters

# Displaying first 5
df.head()
# Out:
#              timestamp           source  \
# 0  2025-06-27 07:20:25        ModernCRM
# 1      1/14/2025 23:07        ModernCRM
# 2       1/17/2025 1:29  AnalyticsEngine
# 3  2025-07-12 00:24:16         ModernHR
# 4  2025-06-02 18:25:23    BillingSystem
#
#                                          log_message    target_label  \
# 0  nova.osapi_compute.wsgi.server [req-b9718cd8-f...     HTTP Status
# 1     Email service experiencing issues with sending  Critical Error
# 2          Unauthorized access to data was attempted  Security Alert
# 3  nova.osapi_compute.wsgi.server [req-4895c258-b...     HTTP Status
# 4  nova.osapi_compute.wsgi.server [req-ee8bc8ba-9...     HTTP Status
#
#   complexity  cluster
# 0       bert        0
# 1       bert        1
# 2       bert        2
# 3       bert        0
# 4       bert        0

# %%
df[df.cluster==1]
# Out:
#              timestamp           source  \
# 1      1/14/2025 23:07        ModernCRM
# 10      8/9/2025 18:58        ModernCRM
# 217     1/22/2025 5:45    BillingSystem
# 248     5/2/2025 23:04         ModernHR
# 265    3/30/2025 23:53        ModernCRM
# 361   11/19/2025 23:06    BillingSystem
# 450    10/27/2025 5:59    ThirdPartyAPI
# 477    12/2/2025 10:30  AnalyticsEngine
# 570    11/7/2025 18:08    ThirdPartyAPI
# 678    4/28/2025 15:13  AnalyticsEngine
# 695    6/30/2025 12:46    ThirdPartyAPI
# 816      7/9/2025 9:38    BillingSystem
# 926     2/17/2025 8:01        ModernCRM
# 1011    2/9/2025 17:04  AnalyticsEngine
# 1018   2/16/2025 15:02    BillingSystem
# 1046  11/26/2025 22:54  AnalyticsEngine
# 1058   10/24/2025 5:37  AnalyticsEngine
# 1082   5/17/2025 11:20         ModernHR
# 1151   6/17/2025 15:13    ThirdPartyAPI
# 1176   10/1/2025 12:27  AnalyticsEngine
# 1189     2/9/2025 6:15        ModernCRM
# 1359   8/18/2025 15:58        ModernCRM
# 1414   6/22/2025 23:07        ModernCRM
# 1427  10/26/2025 20:25         ModernHR
# 1453    9/11/2025 1:18    BillingSystem
# 1554     3/2/2025 9:21        ModernCRM
# 1567   5/11/2025 11:17    ThirdPartyAPI
# 1582    9/10/2025 9:27    BillingSystem
# 1860    6/26/2025 1:08    BillingSystem
# 1867   10/6/2025 11:04        ModernCRM
# 1901    9/22/2025 2:52    ThirdPartyAPI
# 1972    3/12/2025 3:48    ThirdPartyAPI
# 2049   10/1/2025 22:07  AnalyticsEngine
# 2165    4/4/2025 16:11    ThirdPartyAPI
# 2281   3/23/2025 20:12    ThirdPartyAPI
# 2284   10/4/2025 18:15    BillingSystem
# 2312    3/9/2025 21:16         ModernHR
# 2340    3/26/2025 8:10        ModernCRM
# 2408  11/11/2025 11:52    BillingSystem
#
#                                             log_message    target_label  \
# 1        Email service experiencing issues with sending  Critical Error
# 10             Email server encountered a sending fault           Error
# 217          Mail service encountered a delivery glitch           Error
# 248    Service disruption caused by email sending error  Critical Error
# 265           Email system had a problem sending emails           Error
# 361           Email service experienced a sending issue           Error
# 450          Email delivery system encountered an error           Error
# 477      Email transmission error caused service impact  Critical Error
# 570           Email service impacted by sending failure  Critical Error
# 678              Email delivery problem affected system  Critical Error
# 695        Service outage due to email delivery problem  Critical Error
# 816            Error in email delivery affected service  Critical Error
# 926           Email service suffered a delivery failure           Error
# 1011            Error in email sending impacted service  Critical Error
# 1018           Mail service impacted by delivery glitch  Critical Error
# 1046  Email service had a difficulty delivering mess...           Error
# 1058              Email system failed to deliver emails           Error
# 1082           Delivery failure impacted email services  Critical Error
# 1151             Mail service was unable to send emails           Error
# 1176          Email provider faced a delivery challenge           Error
# 1189       Service issue caused by email delivery error  Critical Error
# 1359             Email system down due to sending error  Critical Error
# 1414           Email system encountered a sending error           Error
# 1427          Email provider had trouble sending emails           Error
# 1453         Mail delivery error impacted email service  Critical Error
# 1554     Email system had a difficulty sending messages           Error
# 1567          Email system affected by delivery failure  Critical Error
# 1582   Email delivery failure resulted in service issue  Critical Error
# 1860   Email provider experienced a mail delivery issue           Error
# 1867            Email service had a sending malfunction           Error
# 1901     Email service experienced a mail sending issue           Error
# 1972    Delivery issue with email service caused outage  Critical Error
# 2049        Email server experienced a delivery problem           Error
# 2165       Email server had trouble transmitting emails           Error
# 2281      Mail delivery issue caused service disruption  Critical Error
# 2284       Email service down due to transmission issue  Critical Error
# 2312            Email service faced a delivery obstacle           Error
# 2340     Service outage due to email transmission error  Critical Error
# 2408      Email service affected by failed transmission  Critical Error
#
#      complexity  cluster
# 1          bert        1
# 10         bert        1
# 217        bert        1
# 248        bert        1
# 265        bert        1
# 361        bert        1
# 450        bert        1
# 477        bert        1
# 570        bert        1
# 678        bert        1
# 695        bert        1
# 816        bert        1
# 926        bert        1
# 1011       bert        1
# 1018       bert        1
# 1046       bert        1
# 1058       bert        1
# 1082       bert        1
# 1151       bert        1
# 1176       bert        1
# 1189       bert        1
# 1359       bert        1
# 1414       bert        1
# 1427       bert        1
# 1453       bert        1
# 1554       bert        1
# 1567       bert        1
# 1582       bert        1
# 1860       bert        1
# 1867       bert        1
# 1901       bert        1
# 1972       bert        1
# 2049       bert        1
# 2165       bert        1
# 2281       bert        1
# 2284       bert        1
# 2312       bert        1
# 2340       bert        1
# 2408       bert        1

# %%
# Group by cluster to inspect patterns
clusters = df.groupby('cluster')['log_message'].apply(list)
sorted_clusters = clusters.sort_values(key=lambda x: x.map(len), ascending=False)

# %%
print("Clustered Patterns:")
for cluster_id, messages in sorted_clusters.items():
    if len(messages) > 10:
        print(f"Cluster {cluster_id}:")
        for msg in messages[:5]:
            print(f"  {msg}")
# Out:
# Clustered Patterns:
# Cluster 0:
#   nova.osapi_compute.wsgi.server [req-b9718cd8-f65e-49cc-8349-6cf7122af137 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] 10.11.10.1 "GET /v2/54fadb412c4e40cdbaed9335e4c35a9e/servers/detail HTTP/1.1" status: 200 len: 1893 time: 0.2675118
#   nova.osapi_compute.wsgi.server [req-4895c258-b2f8-488f-a2a3-4fae63982e48 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] 10.11.10.1 "GET /v2/54fadb412c4e40cdbaed9335e4c35a9e/servers/detail HTTP/1.1" HTTP status code -  200 len: 211 time: 0.0968180
#   nova.osapi_compute.wsgi.server [req-ee8bc8ba-9265-4280-9215-dbe000a41209 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] 10.11.10.1 "GET /v2/54fadb412c4e40cdbaed9335e4c35a9e/servers/detail HTTP/1.1" RCODE  200 len: 1874 time: 0.2280791
#   nova.osapi_compute.wsgi.server [req-f0bffbc3-5ab0-4916-91c1-0a61dd7d4ec2 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] 10.11.10.1 "GET /v2/54fadb412c4e40cdbaed9335e4c35a9e/servers/detail HTTP/1.1" Return code: 200 len: 1874 time: 0.2131531
#   nova.osapi_compute.wsgi.server [req-2bf7cfee-a236-42f3-8fb1-96fefab0b302 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] 10.11.10.1 "GET /v2/54fadb412c4e40cdbaed9335e4c35a9e/servers/detail HTTP/1.1" RCODE  200 len: 1874 time: 0.1794369
# Cluster 5:
#   nova.compute.claims [req-a07ac654-8e81-416d-bfbb-189116b07969 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] [instance: bf8c824d-f099-4433-a41e-e3da7578262e] Total memory: 64172 MB, used: 512.00 MB
#   nova.compute.claims [req-d6986b54-3735-4a42-9074-0ba7d9717de9 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] [instance: af5f7392-f7d4-4298-b647-c98924c64aa1] memory limit: 96258.00 MB, free: 95746.00 MB
#   nova.compute.claims [req-72b4858f-049e-49e1-b31e-b562c5018eaf 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] [instance: 63a0d960-70b6-44c6-b606-491478a5cadf] disk limit not specified, defaulting to unlimited
#   nova.compute.claims [req-5c8f52bd-8e3c-41f0-95a5-7861d247cafa 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] [instance: d96a117b-0193-4549-bdcc-63b917273d1d] vcpu limit not specified, defaulting to unlimited
#   nova.compute.claims [req-d38f479d-9bb9-4276-9688-52607e8fd350 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] [instance: 95960536-049b-41f6-9049-05fc479b6a7c] disk limit not specified, defaulting to unlimited
# Cluster 11:
#   User User685 logged out.
#   User User395 logged in.
#   User User225 logged in.
#   User User494 logged out.
#   User User900 logged in.
# Cluster 13:
#   Backup started at 2025-05-14 07:06:55.
#   Backup started at 2025-02-15 20:00:19.
#   Backup ended at 2025-08-08 13:06:23.
#   Backup started at 2025-11-14 08:27:43.
#   Backup started at 2025-12-09 10:19:11.
# Cluster 7:
#   Multiple bad login attempts detected on user 8538 account
#   Multiple login failures occurred on user 9052 account
#   User 7153 made multiple incorrect login attempts
#   User 8300 made multiple incorrect login attempts
#   Multiple login failures were detected for user 6373
# Cluster 8:
#   Backup completed successfully.
#   Backup completed successfully.
#   Backup completed successfully.
#   Backup completed successfully.
#   Backup completed successfully.
# Cluster 21:
#   System updated to version 3.9.1.
#   System updated to version 5.5.4.
#   System updated to version 4.7.4.
#   System updated to version 3.7.7.
#   System updated to version 2.6.2.
# Cluster 3:
#   Shard 6 replication task ended in failure
#   Data replication task for shard 14 did not complete
#   Data replication task failed for shard 17
#   Replication of data to shard 14 failed
#   Data replication task for shard 6 did not complete
# Cluster 4:
#   File data_6169.csv uploaded successfully by user User953.
#   File data_3847.csv uploaded successfully by user User175.
#   File data_7366.csv uploaded successfully by user User282.
#   File data_1206.csv uploaded successfully by user User359.
#   File data_1503.csv uploaded successfully by user User151.
# Cluster 17:
#   Denied access attempt on restricted account Account2682
#   Unauthorized login attempt on protected account Account5030
#   Account Account9437 blocked due to failed login
#   Account Account7999 access denied due to login failure
#   Invalid login attempt made on secured account Account7864
# Cluster 6:
#   Critical system unit error: unit ID Component55
#   System component malfunction: component ID Component79
#   Critical system element is down: element ID Component96
#   Essential system part malfunction: part ID Component6
#   Failure occurred in critical system component: component ID Component92
# Cluster 32:
#   Disk cleanup completed successfully.
#   Disk cleanup completed successfully.
#   Disk cleanup completed successfully.
#   Disk cleanup completed successfully.
#   Disk cleanup completed successfully.
# Cluster 16:
#   System reboot initiated by user User243.
#   System reboot initiated by user User471.
#   System reboot initiated by user User216.
#   System reboot initiated by user User639.
#   System reboot initiated by user User819.
# Cluster 20:
#   User 7662 tried to bypass API security measures
#   User 2367 failed to provide valid API access credentials
#   User 3569 made an unauthorized API request
#   Unauthorized user 2968 tried to access restricted API
#   User 2186 attempted to access API without proper authorization
# Cluster 9:
#   Account with ID 5351 created by User634.
#   Account with ID 7813 created by User373.
#   Account with ID 9827 created by User965.
#   Account with ID 2520 created by User546.
#   Account with ID 2300 created by User964.
# Cluster 1:
#   Email service experiencing issues with sending
#   Email server encountered a sending fault
#   Mail service encountered a delivery glitch
#   Service disruption caused by email sending error
#   Email system had a problem sending emails
# Cluster 10:
#   nova.compute.resource_tracker [req-addc1839-2ed5-4778-b57e-5854eb7b8b09 - - - - -] Final resource view: name=cp-1.slowvm1.tcloud-pg0.utah.cloudlab.us phys_ram=64172MB used_ram=512MB phys_disk=15GB used_disk=0GB total_vcpus=16 used_vcpus=0 pci_stats=[]
#   nova.compute.resource_tracker [req-addc1839-2ed5-4778-b57e-5854eb7b8b09 - - - - -] Final resource view: name=cp-1.slowvm1.tcloud-pg0.utah.cloudlab.us phys_ram=64172MB used_ram=2560MB phys_disk=15GB used_disk=20GB total_vcpus=16 used_vcpus=1 pci_stats=[]
#   nova.compute.resource_tracker [req-addc1839-2ed5-4778-b57e-5854eb7b8b09 - - - - -] Total usable vcpus: 16, total allocated vcpus: 0
#   nova.compute.resource_tracker [req-addc1839-2ed5-4778-b57e-5854eb7b8b09 - - - - -] Final resource view: name=cp-1.slowvm1.tcloud-pg0.utah.cloudlab.us phys_ram=64172MB used_ram=2560MB phys_disk=15GB used_disk=20GB total_vcpus=16 used_vcpus=1 pci_stats=[]
#   nova.compute.resource_tracker [req-addc1839-2ed5-4778-b57e-5854eb7b8b09 - - - - -] Final resource view: name=cp-1.slowvm1.tcloud-pg0.utah.cloudlab.us phys_ram=64172MB used_ram=2560MB phys_disk=15GB used_disk=20GB total_vcpus=16 used_vcpus=1 pci_stats=[]
# Cluster 34:
#   Abnormal behavior found on server 10, possible security threat
#   Security alert: suspicious activity on server 1
#   Anomalous activity identified on server 23, security review recommended
#   Server 27 experienced potential security incident, review required
#   Server 36 experienced potential security incident, review required
# Cluster 53:
#   Module X experienced an invalid data format issue
#   Input format mismatch occurred in module X
#   Module X reported an error in input format validation
#   Module X failed to process input due to formatting error
#   Input data format in module X was invalid or corrupted
# Cluster 14:
#   Detection of multiple disk faults in RAID setup
#   RAID array suffered multiple hard drive failures
#   RAID array experienced multiple disk crashes
#   Multiple hard drive issues in RAID configuration found
#   Identification of multiple faulty disks in RAID array
# Cluster 52:
#   Service health check was not successful because of SSL certificate validation failures.
#   Invalid SSL certificate resulted in a failed service health check.
#   Service health check failure was due to an invalid or improperly configured SSL certificate.
#   An issue with the SSL certificate caused the service health check to fail.
#   Service health check failure was caused by an expired SSL certificate.
# Cluster 18:
#   Boot process terminated unexpectedly due to kernel issue
#   System encountered kernel panic during initialization phase
#   Boot process was stopped by kernel malfunction
#   System encountered kernel failure during bootup sequence
#   Boot sequence failed due to kernel panic
# Cluster 42:
#   User 5127 has escalated admin privileges without authorization
#   User 9745 has escalated to admin level
#   User 8483 escalated privileges to admin level
#   User 1987 has escalated to admin level
#   User 8395 escalated privileges to admin level
# Cluster 25:
#   System configuration is no longer valid
#   Configuration is corrupted throughout the system
#   Cross-system configuration failure occurred
#   System configuration is experiencing errors
#   Configuration malfunction is system-wide
# Cluster 59:
#   Potential security threat: Admin privilege escalation for user 5130
#   Admin privilege escalation alert for user 2893
#   Admin privilege escalation alert for user 8532
#   Potential security threat: Admin privilege escalation for user 1554
#   Warning: Potential admin privilege escalation for user 5720
# Cluster 26:
#   Privilege elevation detected for user 5038
#   Elevation of admin privileges detected for user 6137
#   Elevation of admin privileges detected for user 4907
#   User 6069 has been granted elevated admin privileges
#   Admin privilege elevation warning for user 7574

# %%
import re
def classify_with_regex(log_message):
    regex_patterns = {
        r"User User\d+ logged (in|out).": "User Action",
        r"Backup (started|ended) at .*": "System Notification",
        r"Backup completed successfully.": "System Notification",
        r"System updated to version .*": "System Notification",
        r"File .* uploaded successfully by user .*": "System Notification",
        r"Disk cleanup completed successfully.": "System Notification",
        r"System reboot initiated by user .*": "System Notification",
        r"Account with ID .* created by .*": "User Action"
    }
    for pattern, label in regex_patterns.items():
        if re.search(pattern, log_message, re.IGNORECASE):
            return label
    return None

# %%
classify_with_regex("User User1 logged IN.")
# Out:
# 'User Action'

# %%
classify_with_regex("Hey")

# %%
classify_with_regex("Account with ID 73829 created by Manan")
# Out:
# 'User Action'

# %%
df.shape
# Out:
# (2410, 7)

# %%
# Apply regex classification
df['regex_label'] = df['log_message'].apply(lambda x: classify_with_regex(x))
df[df['regex_label'].notnull()]
# Out:
#             timestamp         source  \
# 7     10/11/2025 8:44       ModernHR
# 14      1/4/2025 1:43  ThirdPartyAPI
# 15      5/1/2025 9:41      ModernCRM
# 18    2/22/2025 17:49      ModernCRM
# 27    9/24/2025 19:57  ThirdPartyAPI
# ...               ...            ...
# 2376   6/27/2025 8:47      ModernCRM
# 2381    9/5/2025 6:39  ThirdPartyAPI
# 2394   4/3/2025 13:13       ModernHR
# 2395   5/2/2025 14:29  ThirdPartyAPI
# 2403   10/1/2025 1:31      ModernCRM
#
#                                             log_message         target_label  \
# 7     File data_6169.csv uploaded successfully by us...  System Notification
# 14    File data_3847.csv uploaded successfully by us...  System Notification
# 15                       Backup completed successfully.  System Notification
# 18             Account with ID 5351 created by User634.          User Action
# 27                             User User685 logged out.          User Action
# ...                                                 ...                  ...
# 2376                   System updated to version 2.0.5.  System Notification
# 2381               Disk cleanup completed successfully.  System Notification
# 2394               Disk cleanup completed successfully.  System Notification
# 2395               Backup ended at 2025-05-06 11:23:16.  System Notification
# 2403                     Backup completed successfully.  System Notification
#
#      complexity  cluster          regex_label
# 7         regex        4  System Notification
# 14        regex        4  System Notification
# 15        regex        8  System Notification
# 18        regex        9          User Action
# 27        regex       11          User Action
# ...         ...      ...                  ...
# 2376      regex       21  System Notification
# 2381      regex       32  System Notification
# 2394      regex       32  System Notification
# 2395      regex       13  System Notification
# 2403      regex        8  System Notification
#
# [500 rows x 7 columns]

# %%
df[df['regex_label'].notnull()].shape
# Out:
# (500, 7)

# %%
df_non_regex = df[df['regex_label'].isnull()].copy()
df_non_regex.shape
df_non_regex
# Out:
#                 timestamp           source  \
# 0     2025-06-27 07:20:25        ModernCRM
# 1         1/14/2025 23:07        ModernCRM
# 2          1/17/2025 1:29  AnalyticsEngine
# 3     2025-07-12 00:24:16         ModernHR
# 4     2025-06-02 18:25:23    BillingSystem
# ...                   ...              ...
# 2405  2025-08-13 07:29:25         ModernHR
# 2406       1/11/2025 5:32         ModernHR
# 2407  2025-08-03 03:07:47    ThirdPartyAPI
# 2408     11/11/2025 11:52    BillingSystem
# 2409     12/25/2025 13:21  AnalyticsEngine
#
#                                             log_message    target_label  \
# 0     nova.osapi_compute.wsgi.server [req-b9718cd8-f...     HTTP Status
# 1        Email service experiencing issues with sending  Critical Error
# 2             Unauthorized access to data was attempted  Security Alert
# 3     nova.osapi_compute.wsgi.server [req-4895c258-b...     HTTP Status
# 4     nova.osapi_compute.wsgi.server [req-ee8bc8ba-9...     HTTP Status
# ...                                                 ...             ...
# 2405  nova.osapi_compute.wsgi.server [req-96c3ec98-2...     HTTP Status
# 2406  User 3844 account experienced multiple failed ...  Security Alert
# 2407  nova.metadata.wsgi.server [req-b6d4a270-accb-4...     HTTP Status
# 2408      Email service affected by failed transmission  Critical Error
# 2409  Repeated failed login attempts occurred for us...  Security Alert
#
#      complexity  cluster regex_label
# 0          bert        0        None
# 1          bert        1        None
# 2          bert        2        None
# 3          bert        0        None
# 4          bert        0        None
# ...         ...      ...         ...
# 2405       bert        0        None
# 2406       bert        7        None
# 2407       bert        0        None
# 2408       bert        1        None
# 2409       bert        7        None
#
# [1910 rows x 7 columns]

# %%
print(df_non_regex['target_label'].value_counts()[df_non_regex['target_label'].value_counts()<=5].index.tolist())
# Out:
# ['Workflow Error', 'Deprecation Warning']

# %%
df_legacy = df_non_regex[df_non_regex.source=="LegacyCRM"]
df_legacy
# Out:
#                 timestamp     source  \
# 60    2025-10-06 16:55:23  LegacyCRM
# 255   2025-05-03 16:55:35  LegacyCRM
# 377   2025-06-24 12:16:29  LegacyCRM
# 1325  2025-04-17 07:33:44  LegacyCRM
# 1734  2025-04-30 07:47:30  LegacyCRM
# 1826  2025-01-23 10:33:36  LegacyCRM
# 2217  2025-05-12 09:46:54  LegacyCRM
#
#                                             log_message         target_label  \
# 60    Lead conversion failed for prospect ID 7842 du...       Workflow Error
# 255   API endpoint 'getCustomerDetails' is deprecate...  Deprecation Warning
# 377   Customer follow-up process for lead ID 5621 fa...       Workflow Error
# 1325  Escalation rule execution failed for ticket ID...       Workflow Error
# 1734  The 'ExportToCSV' feature is outdated. Please ...  Deprecation Warning
# 1826  Support for legacy authentication methods will...  Deprecation Warning
# 2217  Task assignment for TeamID 3425 could not comp...       Workflow Error
#
#      complexity  cluster regex_label
# 60          llm       24        None
# 255         llm       48        None
# 377         llm       62        None
# 1325        llm      105        None
# 1734        llm      118        None
# 1826        llm      122        None
# 2217        llm      133        None

# %%
df_legacy.source.unique()
# Out:
# array(['LegacyCRM'], dtype=object)

# %%
df_non_legacy = df_non_regex[df_non_regex.source!="LegacyCRM"]
df_non_legacy
# Out:
#                 timestamp           source  \
# 0     2025-06-27 07:20:25        ModernCRM
# 1         1/14/2025 23:07        ModernCRM
# 2          1/17/2025 1:29  AnalyticsEngine
# 3     2025-07-12 00:24:16         ModernHR
# 4     2025-06-02 18:25:23    BillingSystem
# ...                   ...              ...
# 2405  2025-08-13 07:29:25         ModernHR
# 2406       1/11/2025 5:32         ModernHR
# 2407  2025-08-03 03:07:47    ThirdPartyAPI
# 2408     11/11/2025 11:52    BillingSystem
# 2409     12/25/2025 13:21  AnalyticsEngine
#
#                                             log_message    target_label  \
# 0     nova.osapi_compute.wsgi.server [req-b9718cd8-f...     HTTP Status
# 1        Email service experiencing issues with sending  Critical Error
# 2             Unauthorized access to data was attempted  Security Alert
# 3     nova.osapi_compute.wsgi.server [req-4895c258-b...     HTTP Status
# 4     nova.osapi_compute.wsgi.server [req-ee8bc8ba-9...     HTTP Status
# ...                                                 ...             ...
# 2405  nova.osapi_compute.wsgi.server [req-96c3ec98-2...     HTTP Status
# 2406  User 3844 account experienced multiple failed ...  Security Alert
# 2407  nova.metadata.wsgi.server [req-b6d4a270-accb-4...     HTTP Status
# 2408      Email service affected by failed transmission  Critical Error
# 2409  Repeated failed login attempts occurred for us...  Security Alert
#
#      complexity  cluster regex_label
# 0          bert        0        None
# 1          bert        1        None
# 2          bert        2        None
# 3          bert        0        None
# 4          bert        0        None
# ...         ...      ...         ...
# 2405       bert        0        None
# 2406       bert        7        None
# 2407       bert        0        None
# 2408       bert        1        None
# 2409       bert        7        None
#
# [1903 rows x 7 columns]

# %%
df_non_legacy.source.unique()
# Out:
# array(['ModernCRM', 'AnalyticsEngine', 'ModernHR', 'BillingSystem',
#        'ThirdPartyAPI'], dtype=object)

# %%
filtered_embeddings = model.encode(df_non_legacy['log_message'].tolist())
filtered_embeddings[:2]
# Out:
# array([[-1.02939598e-01,  3.35459486e-02, -2.20260844e-02,
#          1.55103172e-03, -9.86921880e-03, -1.78956211e-01,
#         -6.34409934e-02, -6.01761453e-02,  2.81108953e-02,
#          5.99620081e-02, -1.72618236e-02,  1.43364200e-03,
#         -1.49560079e-01,  3.15288268e-03, -5.66030741e-02,
#          2.71685328e-02, -1.49890278e-02, -3.54037210e-02,
#         -3.62936370e-02, -1.45410486e-02, -5.61492983e-03,
#          8.75538811e-02,  4.55120727e-02,  2.50963680e-02,
#          1.00187613e-02,  1.24267004e-02, -1.39923558e-01,
#          7.68696666e-02,  3.14095393e-02, -4.15247958e-03,
#          4.36902344e-02,  1.71249956e-02, -8.00950900e-02,
#          5.74006140e-02,  1.89092122e-02,  8.55262056e-02,
#          3.96399088e-02, -1.34371832e-01, -1.44367013e-03,
#          3.06707830e-03,  1.76854059e-01,  4.44890792e-03,
#         -1.69275142e-02,  2.24266183e-02, -4.35049757e-02,
#          6.09031972e-03, -9.98171885e-03, -6.23973012e-02,
#          1.07372692e-02, -6.04895223e-03, -7.14661255e-02,
#         -8.45800899e-03, -3.18019874e-02, -1.00518353e-01,
#          2.25892727e-04, -1.89341605e-02, -3.17793749e-02,
#          4.00861092e-02,  2.19178014e-02, -2.59528570e-02,
#          5.84524833e-02, -8.12509656e-02,  2.12029386e-02,
#         -5.02687544e-02,  1.32056857e-02,  1.32681162e-03,
#          2.27062758e-02, -3.45794074e-02,  3.91546786e-02,
#         -2.09433492e-02,  3.24822357e-03,  4.43961024e-02,
#         -9.85358134e-02, -2.88895480e-02, -6.85024215e-03,
#          5.38819097e-02,  6.46110177e-02, -2.45060828e-02,
#          9.21828821e-02, -7.49868974e-02,  1.23994965e-02,
#         -1.00026578e-01, -4.64910679e-02,  6.01569898e-02,
#         -2.46480461e-02, -7.08076060e-02, -2.77271084e-02,
#          9.72610563e-02,  3.85841243e-02, -1.44293215e-02,
#         -7.46876060e-04, -1.04305558e-02, -1.61843076e-02,
#          4.43628244e-02,  9.25995782e-03,  7.14165643e-02,
#          6.37917668e-02,  4.94931154e-02, -6.02567866e-02,
#          4.04805355e-02, -3.42860296e-02, -1.93881392e-02,
#          6.61234260e-02,  6.01589940e-02,  1.09371496e-02,
#         -5.38629945e-03,  1.44580016e-02,  9.25429761e-02,
#         -3.14564258e-02, -1.84351988e-02,  9.91879404e-03,
#         -1.85574368e-02,  1.31281465e-03,  2.26563407e-05,
#          2.02739448e-03,  2.75256820e-02, -4.81927916e-02,
#          5.42825609e-02, -7.32067153e-02,  4.88667339e-02,
#          4.98489924e-02, -9.01142415e-03, -4.68906164e-02,
#         -4.25886661e-02, -8.19523782e-02,  3.87106054e-02,
#          7.85503089e-02,  1.46077052e-32,  1.66706461e-02,
#          5.25494032e-02, -1.82448998e-02, -1.26686115e-02,
#          6.52837232e-02, -2.11777352e-02, -4.06322591e-02,
#          4.14947644e-02, -2.48361286e-02, -1.33068012e-02,
#         -5.46753965e-02, -5.99142280e-04, -4.89243725e-03,
#         -6.27359226e-02, -3.84878181e-02, -6.13544025e-02,
#          8.27405304e-02,  2.34380104e-02, -8.63093510e-03,
#          1.31002879e-02,  6.44215271e-02, -4.41361666e-02,
#         -6.98633343e-02, -7.36060143e-02, -4.33264077e-02,
#          6.96524372e-03, -5.05956821e-02, -1.60911884e-02,
#         -5.66794015e-02,  3.35454172e-03,  5.34114838e-02,
#          2.47761123e-02, -1.47985769e-02, -2.93243285e-02,
#          7.30227977e-02, -1.86834130e-02,  8.13137144e-02,
#         -2.69967336e-02, -5.68056144e-02, -6.59389123e-02,
#         -5.95397688e-03,  2.85312925e-02, -7.85358027e-02,
#         -2.76694074e-03, -3.26468586e-03, -9.28333029e-02,
#         -7.27362633e-02, -3.31903175e-02,  1.01411082e-01,
#          9.79882032e-02, -9.78740007e-02,  1.98667496e-02,
#          2.38837264e-02, -1.81672256e-02, -3.73709053e-02,
#          1.96549576e-03,  6.34426102e-02,  1.18271522e-02,
#         -1.12041505e-02, -3.87316383e-02,  9.32424143e-02,
#          4.26629651e-03, -1.66872405e-02, -6.87463954e-02,
#          1.55120483e-02, -4.97755222e-02,  3.34492959e-02,
#          8.00032243e-02,  2.12281905e-02,  1.34581909e-01,
#         -2.30729971e-02,  5.53858466e-02,  3.07558216e-02,
#         -2.93905493e-02,  2.31905486e-02, -9.34308171e-02,
#          7.58034810e-02, -5.21205226e-03, -5.14523126e-02,
#          3.32689323e-02,  3.67963053e-02, -1.06449798e-02,
#          1.01635531e-02, -2.07651500e-02, -5.85519001e-02,
#          4.79328074e-02,  2.13694833e-02,  8.76213238e-02,
#          3.35493730e-03, -3.80336605e-02, -1.81204714e-02,
#          6.87452592e-03,  5.15879989e-02, -4.75598574e-02,
#         -6.12065159e-02, -1.45483530e-32,  4.12800722e-03,
#          4.59645316e-03, -5.63900769e-02,  4.32465272e-03,
#         -1.09440682e-03,  9.31954570e-03, -2.20268667e-02,
#          5.79564609e-02, -1.44787570e-02,  4.64155599e-02,
#          1.43542871e-01, -6.89756721e-02,  6.09631836e-02,
#         -8.93743858e-02,  2.40919348e-02,  2.06010714e-02,
#         -2.82416046e-02, -6.48315102e-02,  5.64795919e-02,
#         -7.48339668e-03, -3.52058560e-02,  8.51060450e-02,
#          1.30359819e-02,  2.02257708e-02, -1.44390967e-02,
#         -4.63718660e-02,  1.77209731e-02,  1.59105621e-02,
#         -9.51009467e-02, -3.54526788e-02,  2.08696090e-02,
#          3.84385232e-03, -8.77917930e-02,  6.44575506e-02,
#          1.44171612e-02,  3.84729309e-03,  4.70991693e-02,
#          4.94661517e-02,  1.53862564e-02, -2.59578731e-02,
#          9.10894498e-02,  1.83307920e-02, -5.89206219e-02,
#          2.51993146e-02, -3.30373794e-02,  8.23344663e-02,
#          1.74791757e-02,  6.48047403e-02, -1.19674262e-02,
#         -3.31778415e-02,  3.00177317e-02,  3.54220085e-02,
#         -1.39624514e-02,  6.69272989e-02,  3.87919620e-02,
#          6.06916696e-02,  1.17957848e-03, -2.38786284e-02,
#         -1.26930490e-01,  1.13846632e-02,  1.59290060e-02,
#         -1.29426625e-02, -8.63247439e-02,  8.53660703e-03,
#          6.03761636e-02,  1.51122436e-02, -1.19132407e-01,
#          1.15234470e-02,  5.97089268e-02, -3.93345952e-02,
#          1.55673148e-02,  1.04602342e-02, -4.72457036e-02,
#         -2.59243064e-02,  9.98528209e-03,  3.07146013e-02,
#         -7.14844689e-02,  6.98967557e-03, -1.55133186e-02,
#          2.18864325e-02, -2.78145522e-02,  6.92733154e-02,
#         -2.75903475e-02,  2.62429547e-02,  3.52561995e-02,
#         -4.26419415e-02,  7.46284961e-04,  6.59867302e-02,
#         -5.15105650e-02, -3.58434208e-02, -6.53442135e-03,
#         -2.75858492e-02, -1.00125544e-01,  7.83325955e-02,
#         -1.45798773e-02, -6.18457179e-08,  2.00325623e-02,
#          6.59785196e-02, -2.04702597e-02,  1.64043866e-02,
#          7.63001367e-02,  7.32182786e-02,  5.65787451e-03,
#         -6.97761949e-04, -3.63798416e-03,  6.02394454e-02,
#         -3.27187367e-02, -6.45837858e-02, -5.97952567e-02,
#         -1.76695641e-02,  6.10140571e-03, -5.63489553e-03,
#         -1.22972250e-01,  6.35818541e-02, -2.19431613e-02,
#         -1.16406471e-01,  2.34366171e-02, -7.23525435e-02,
#          2.31773816e-02, -6.55986890e-02, -7.42681623e-02,
#          2.60146093e-02,  3.59758511e-02,  7.68432766e-02,
#         -3.08057144e-02, -2.34793816e-02, -6.30426183e-02,
#         -3.62158455e-02, -1.03560099e-02, -4.75602038e-02,
#         -2.87521929e-02,  2.96400692e-02, -5.26895793e-03,
#          5.67889959e-02, -3.74493655e-03,  3.09612677e-02,
#          3.48227136e-02,  3.78607735e-02,  2.10155528e-02,
#          2.70691440e-02,  5.25520556e-02,  7.16229603e-02,
#         -5.53756254e-03,  4.01094146e-02,  5.16276918e-02,
#         -2.67314091e-02,  5.94224073e-02, -4.29224223e-02,
#         -1.19760558e-02,  3.05985250e-02, -7.40331709e-02,
#          1.84221864e-02, -8.64861067e-03, -8.83557424e-02,
#         -5.91984391e-02, -1.00883713e-04,  1.12913661e-01,
#          4.57792962e-03, -4.25971635e-02,  3.22622969e-03],
#        [ 8.04572552e-03, -3.57392393e-02,  4.93873879e-02,
#         -7.19184428e-03,  6.17668557e-04, -9.05685127e-02,
#          5.75595051e-02, -4.39446084e-02,  1.74751449e-02,
#          5.21203019e-02, -4.62332182e-02,  2.49039270e-02,
#          4.80811708e-02,  6.86636493e-02,  3.56146768e-02,
#          3.00089214e-02,  2.61449665e-02, -9.05241296e-02,
#         -8.02174062e-02,  5.04851379e-02, -7.90870339e-02,
#         -1.76856481e-03, -2.48926803e-02,  9.02152583e-02,
#          5.83700649e-03, -6.91071302e-02, -6.67965934e-02,
#         -6.99112937e-03, -1.04566008e-01, -2.66473945e-02,
#          3.05639971e-02,  2.02934481e-02,  2.25454997e-02,
#         -4.22683218e-03,  1.11173103e-02,  6.78260922e-02,
#          1.06073283e-02,  7.56636411e-02, -8.22777972e-02,
#          8.45729839e-03, -6.97612464e-02, -4.21974547e-02,
#         -1.05674835e-02,  2.23673303e-02,  5.64496815e-02,
#          8.16503447e-03,  1.09344080e-01,  3.16565149e-02,
#         -1.76923834e-02, -3.21071483e-02, -3.39975841e-02,
#         -4.91824176e-04,  3.72874900e-03,  2.83771716e-02,
#         -1.28521975e-02, -1.07929704e-03, -6.32418990e-02,
#          6.89901039e-02,  1.77270342e-02, -5.20959757e-02,
#          8.28306563e-03,  5.45033030e-02, -5.42099476e-02,
#         -4.53332886e-02, -4.07494120e-02, -2.82698292e-02,
#          1.23605812e-02, -2.13816036e-02, -2.36265752e-02,
#          1.25317667e-02, -2.37170774e-02,  3.97411510e-02,
#         -1.24362260e-01,  7.60625154e-02,  5.50833866e-02,
#          8.28216970e-02,  2.97118686e-02, -1.84067395e-02,
#         -1.96195096e-02,  5.54319844e-02, -3.49144898e-02,
#         -4.14678082e-02, -3.37047167e-02,  7.31323957e-02,
#          4.41836491e-02,  2.55246554e-02, -8.26407690e-03,
#         -1.07323052e-02, -4.26244102e-02, -2.84965336e-03,
#          7.38559365e-02,  2.27768235e-02,  7.15367496e-04,
#          4.36012410e-02,  5.09079620e-02,  6.38482794e-02,
#         -2.73155775e-02, -6.55020997e-02, -7.69265220e-02,
#          3.55171263e-02,  9.60493460e-02,  2.18195748e-02,
#          1.20154498e-02, -1.17863659e-02, -4.57923487e-03,
#         -8.58035777e-03,  3.37151103e-02,  2.31918078e-02,
#         -7.58325234e-02, -5.23879528e-02,  4.53934260e-02,
#         -3.80786173e-02, -3.34904902e-02,  9.20352712e-02,
#          2.87688486e-02, -3.33816819e-02, -1.95854483e-03,
#         -3.04567831e-04, -1.70498900e-02,  2.85335761e-02,
#         -8.81096795e-02, -4.02253121e-02, -4.00093235e-02,
#         -1.03193168e-02, -2.51968503e-02,  2.14093234e-02,
#          1.31045222e-01, -5.29632066e-34, -1.09651729e-01,
#          1.29811466e-02,  5.92660019e-03,  4.73506376e-02,
#         -8.60298425e-03, -3.67089435e-02,  3.05214953e-02,
#          5.53066693e-02, -4.71985452e-02, -1.25118904e-02,
#         -1.15366429e-01,  9.08000953e-03,  1.07346512e-01,
#         -4.94734608e-02, -1.34290364e-02, -4.61562984e-02,
#          2.45320387e-02,  9.45075974e-03,  2.04323996e-02,
#         -3.99918705e-02, -4.67825718e-02,  2.21171733e-02,
#         -4.58187088e-02, -8.13276228e-03, -7.65674515e-03,
#          1.92284770e-02,  4.85845245e-02, -2.55903229e-02,
#          1.61543780e-03, -1.37180379e-02,  9.67301708e-03,
#          7.36416224e-03,  1.14088161e-02,  1.28853455e-01,
#          7.71834888e-03,  7.06362575e-02,  2.54452080e-02,
#          4.06523831e-02,  2.44039763e-02,  1.43777151e-02,
#         -6.00932278e-02,  7.38180354e-02, -2.44700685e-02,
#          8.98901448e-02,  3.17049143e-03,  1.01834461e-01,
#          4.17742170e-02, -5.95177710e-02, -3.23181450e-02,
#          3.80938686e-02,  1.21156052e-02, -4.07834128e-02,
#          2.84823179e-02,  4.90988754e-02, -9.35705751e-03,
#          6.50074407e-02,  7.23532289e-02, -1.67793669e-02,
#         -8.22419114e-03, -1.61573272e-02,  5.96225597e-02,
#         -3.36083509e-02,  2.12108437e-02, -6.06090687e-02,
#          1.54377639e-01, -7.24146217e-02, -3.77272367e-02,
#         -3.26890349e-02, -1.80384610e-03, -1.01960413e-02,
#         -1.60677417e-03, -6.91846386e-02,  8.28444585e-02,
#          9.88839567e-02,  3.45466728e-03, -9.90247950e-02,
#         -3.52827050e-02, -7.13178813e-02, -4.96000163e-02,
#         -3.43954526e-02, -8.13041851e-02,  4.81447987e-02,
#          5.00680692e-03, -2.21499726e-02, -5.60056493e-02,
#          1.00067109e-02, -3.59794237e-02,  1.06184304e-01,
#         -4.54196818e-02,  7.16393366e-02, -2.36772913e-02,
#          9.98142548e-03,  2.73602176e-02,  1.05985478e-01,
#          4.60164063e-02,  9.59027617e-34, -1.12306945e-01,
#          2.78912578e-02, -3.35900523e-02,  5.39242998e-02,
#         -2.22291518e-02,  1.53769441e-02,  3.10411584e-02,
#          3.39010768e-02,  7.43167102e-02,  3.42470929e-02,
#         -3.35054635e-03, -2.05350593e-02, -3.62370312e-02,
#          2.29334217e-02, -3.01991943e-02, -1.00819923e-01,
#          3.29194255e-02,  6.77542761e-02,  1.35644944e-02,
#         -5.20547107e-03, -6.58158809e-02,  9.54550579e-02,
#         -1.34039326e-02,  1.53885940e-02, -7.22935945e-02,
#          9.67835709e-02, -8.08119699e-02, -4.53452626e-03,
#         -6.42011985e-02, -4.99278642e-02,  4.64197397e-02,
#          2.21341085e-02,  3.13109383e-02,  9.13569182e-02,
#         -4.61120121e-02, -1.02761187e-01,  3.04416120e-02,
#          5.09876460e-02,  6.70140833e-02,  1.04043270e-02,
#          1.63533799e-02,  3.92030850e-02,  2.17153914e-02,
#          5.36603518e-02,  3.62809636e-02, -4.22140211e-02,
#         -2.47227196e-02,  1.90311782e-02,  3.61724123e-02,
#          6.37021139e-02, -3.21578817e-03, -8.50387383e-03,
#          3.94655615e-02,  9.02654510e-03,  1.93095915e-02,
#          6.60717934e-02,  1.02694957e-02, -4.43853773e-02,
#         -1.56523194e-02, -1.55714676e-02,  1.32904388e-02,
#         -1.16108488e-02,  4.21832129e-02, -5.44776581e-02,
#          1.29237175e-01, -2.25756541e-02,  5.26203774e-02,
#         -1.58436857e-02,  9.33164880e-02,  6.38023904e-03,
#         -9.36165638e-03, -6.08876199e-02, -3.27308029e-02,
#         -3.44816707e-02,  3.29974256e-02, -4.79391702e-02,
#         -9.81300846e-02,  2.91164871e-02, -2.70903241e-02,
#          1.81866642e-02, -1.73860174e-02, -4.40371595e-02,
#         -7.97002390e-02,  3.01647373e-02, -6.35260642e-02,
#          1.25963567e-02,  8.50250348e-02, -4.58910652e-02,
#          5.81016764e-02, -2.71002036e-02,  8.42775702e-02,
#         -4.09972519e-02, -3.37655805e-02,  1.02087930e-02,
#         -2.54193563e-02, -1.40610297e-08,  4.94446792e-02,
#         -9.04356763e-02, -6.06710315e-02,  8.29529092e-02,
#         -3.29032838e-02,  4.14910503e-02,  9.99593921e-03,
#          6.96134334e-03,  3.99234612e-03, -3.24333161e-02,
#         -3.14657018e-02, -5.33161685e-02, -3.80913243e-02,
#          1.62076969e-02,  2.45778412e-02, -7.26419687e-02,
#         -6.56893179e-02, -8.23132172e-02, -8.00500587e-02,
#         -5.36649115e-02,  5.60894459e-02, -1.10913245e-02,
#          9.62154008e-04, -1.22690305e-01, -5.13836592e-02,
#          9.96704213e-03,  1.00696208e-02,  1.07073084e-01,
#          1.19758435e-02,  1.00423899e-02, -6.28261715e-02,
#         -7.49697462e-02, -6.34075888e-03, -2.72201151e-02,
#         -1.28096193e-01, -2.62459628e-02, -1.81463920e-02,
#         -9.85360220e-02, -3.02990526e-02, -4.02614959e-02,
#          9.94291380e-02,  5.35999611e-02,  2.74899788e-02,
#         -5.53685380e-03,  8.43571350e-02,  8.35162252e-02,
#          3.74305025e-02,  7.11937472e-02,  2.98902746e-02,
#          2.32728813e-02, -3.62111628e-02,  6.20540269e-02,
#          2.15148460e-02,  5.19732684e-02,  1.45337591e-02,
#         -4.60966565e-02,  5.02554327e-02, -7.27027506e-02,
#          2.92779077e-02,  5.62663190e-02, -3.86354737e-02,
#          1.53832054e-02, -6.23095073e-02, -2.77466383e-02]], dtype=float32)

# %%
len(filtered_embeddings)
# Out:
# 1903

# %% [markdown]
# # Training Model

# %%
X = filtered_embeddings
y = df_non_legacy['target_label'].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#                 precision    recall  f1-score   support
#
# Critical Error       0.91      1.00      0.95        48
#          Error       0.98      0.89      0.93        47
#    HTTP Status       1.00      1.00      1.00       304
# Resource Usage       1.00      1.00      1.00        49
# Security Alert       1.00      0.99      1.00       123
#
#       accuracy                           0.99       571
#      macro avg       0.98      0.98      0.98       571
#   weighted avg       0.99      0.99      0.99       571

# %%
import joblib

# %%
joblib.dump(clf, 'log_classifier.joblib')
# Out:
# ['log_classifier.joblib']
